# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
# %matplotlib inline
plt.gray()
for i in range(9):
    plt.matshow(digits.images[i])

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(digits.data,digits.target, test_size = 0.2)

# %%
x_train.shape
# Out:
# (1437, 64)

# %%
y_train.shape
# Out:
# (1437,)

# %%
model = linear_model.LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\ARIF RAJA MONDAL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([7, 1, 9, 4, 4, 3, 2, 1, 3, 8, 4, 8, 1, 6, 3, 2, 5, 5, 8, 1, 6, 3,
#        7, 2, 4, 4, 8, 7, 6, 6, 7, 8, 9, 4, 0, 6, 7, 0, 8, 9, 4, 1, 2, 7,
#        9, 1, 2, 3, 2, 9, 8, 5, 2, 0, 0, 7, 0, 9, 6, 9, 6, 1, 7, 9, 3, 7,
#        5, 0, 4, 5, 5, 4, 7, 6, 8, 9, 8, 9, 8, 7, 3, 3, 5, 9, 7, 0, 9, 8,
#        6, 2, 7, 6, 0, 4, 7, 3, 9, 5, 5, 4, 6, 8, 1, 6, 5, 9, 4, 2, 8, 9,
#        1, 7, 9, 5, 2, 1, 2, 8, 7, 3, 7, 0, 5, 1, 8, 8, 9, 3, 1, 3, 5, 3,
#        2, 8, 9, 2, 5, 1, 0, 8, 8, 0, 0, 9, 3, 5, 1, 5, 4, 1, 7, 9, 1, 6,
#        7, 3, 7, 2, 0, 9, 1, 1, 8, 9, 2, 0, 3, 8, 1, 9, 3, 0, 5, 1, 5, 5,
#        1, 1, 3, 8, 3, 1, 0, 9, 2, 8, 8, 4, 9, 1, 4, 1, 2, 5, 0, 9, 6, 8,
#        7, 7, 6, 7, 4, 3, 6, 2, 6, 8, 4, 9, 0, 5, 5, 7, 3, 0, 4, 8, 5, 2,
#        1, 0, 9, 6, 2, 4, 1, 6, 3, 1, 7, 7, 0, 1, 8, 5, 7, 4, 3, 8, 3, 0,
#        6, 7, 5, 5, 1, 6, 2, 5, 8, 4, 5, 2, 4, 7, 5, 8, 8, 1, 1, 1, 4, 0,
#        1, 0, 2, 9, 0, 2, 0, 2, 3, 4, 2, 5, 2, 5, 1, 0, 9, 1, 3, 6, 0, 9,
#        0, 4, 4, 7, 3, 9, 6, 5, 7, 2, 6, 6, 0, 1, 0, 9, 9, 4, 6, 1, 3, 6,
#        9, 3, 2, 4, 3, 0, 3, 9, 3, 2, 3, 5, 9, 4, 5, 6, 7, 4, 7, 6, 1, 7,
#        1, 6, 3, 9, 0, 8, 9, 9, 0, 5, 6, 0, 6, 1, 0, 7, 6, 8, 5, 8, 6, 2,
#        9, 7, 4, 2, 1, 9, 8, 4])

# %%
model.score(x_test,y_test)
# Out:
# 0.9694444444444444

# %%
plt.matshow(digits.images[87])

# %%
model.predict([digits.data[87]])
# Out:
# array([4])

# %%
model.predict(digits.data[:7])
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
y_predicted = model.predict(x_test) 
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test,y_predicted)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot = True)
plt.xlabel('Prediction')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
